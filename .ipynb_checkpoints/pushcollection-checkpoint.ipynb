# %%
import pymongo
import dns

# %%
client = pymongo.MongoClient("mongodb+srv://ziningque:YEUr10y8rOWjy15I@cluster0.hzswklr.mongodb.net/test")
db = client.test
collection = db.Movie

# %%
# Read the video file from your local storage and convert it to binary format
with open("public/videos/tabletennis.mp4", "rb") as f:
    video_binary = f.read()

# Read the thumbnail image file from your local storage and convert it to binary format
with open("public/images/thumbnail-1.png", "rb") as f:
    thumbnail_binary = f.read()

# %%
# Create a dictionary object with the necessary fields
movie_dict = {
    "title": "Mandarin Daily News Cup",
    "description": "The Mandarin Daily News Cup is not just about the competition, however. It is also an opportunity for players to connect and build relationships with others who share their passion for the sport. ",
    "videoUrl": "gridfs",
    "thumbnailUrl": thumbnail_binary,
    "genre": "Sports",
    "duration": "18 minutes"
}

# %%
result = collection.insert_one(movie_dict)
print("Inserted document with ID:", result.inserted_id)
# Out:
# ---------------------------------------------------------------------------
# DocumentTooLarge                          Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 result = collection.insert_one(movie_dict)
#       2 print("Inserted document with ID:", result.inserted_id)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:705, in Collection.insert_one(self, document, bypass_document_validation, session)
#     701     document["_id"] = ObjectId()
#     703 write_concern = self._write_concern_for(session)
#     704 return InsertOneResult(
# --> 705     self._insert(document,
#     706                  write_concern=write_concern,
#     707                  bypass_doc_val=bypass_document_validation,
#     708                  session=session),
#     709     write_concern.acknowledged)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:620, in Collection._insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     618 """Internal insert helper."""
#     619 if isinstance(docs, abc.Mapping):
# --> 620     return self._insert_one(
#     621         docs, ordered, check_keys, manipulate, write_concern, op_id,
#     622         bypass_doc_val, session)
#     624 ids = []
#     626 if manipulate:
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:609, in Collection._insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     597     result = sock_info.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         client=self.__database.client,
#     605         retryable_write=retryable_write)
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(
#     610     acknowledged, _insert_command, session)
#     612 if not isinstance(doc, RawBSONDocument):
#     613     return doc.get('_id')
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1552, in MongoClient._retryable_write(self, retryable, func, session)
#    1550 """Internal retryable write helper."""
#    1551 with self._tmp_session(session) as s:
# -> 1552     return self._retry_with_session(retryable, func, s, None)
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1438, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1429 """Execute an operation with at most one consecutive retries
#    1430
#    1431 Returns func()'s return value on success. On error retries the same
#    (...)
#    1434 Re-raises any exception thrown by func().
#    1435 """
#    1436 retryable = (retryable and self.retry_writes
#    1437              and session and not session.in_transaction)
# -> 1438 return self._retry_internal(retryable, func, session, bulk)
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1470, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1468                 raise last_error
#    1469             retryable = False
# -> 1470         return func(session, sock_info, retryable)
#    1471 except ServerSelectionTimeoutError:
#    1472     if is_retrying():
#    1473         # The application may think the write was never attempted
#    1474         # if we raise ServerSelectionTimeoutError on the retry
#    1475         # attempt. Raise the original exception instead.
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:597, in Collection._insert_one.<locals>._insert_command(session, sock_info, retryable_write)
#     594 if bypass_doc_val and sock_info.max_wire_version >= 4:
#     595     command['bypassDocumentValidation'] = True
# --> 597 result = sock_info.command(
#     598     self.__database.name,
#     599     command,
#     600     write_concern=write_concern,
#     601     codec_options=self.__write_response_codec_options,
#     602     check_keys=check_keys,
#     603     session=session,
#     604     client=self.__database.client,
#     605     retryable_write=retryable_write)
#     607 _check_write_command_response(result)
#
# File ~\anaconda3\lib\site-packages\pymongo\pool.py:726, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     724 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     725 except BaseException as error:
# --> 726     self._raise_connection_failure(error)
#
# File ~\anaconda3\lib\site-packages\pymongo\pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~\anaconda3\lib\site-packages\pymongo\network.py:133, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     127     request_id, msg, size = message.query(
#     128         flags, ns, 0, -1, spec, None, codec_options, check_keys,
#     129         compression_ctx)
#     131 if (max_bson_size is not None
#     132         and size > max_bson_size + message._COMMAND_OVERHEAD):
# --> 133     message._raise_document_too_large(
#     134         name, size, max_bson_size + message._COMMAND_OVERHEAD)
#     136 if publish:
#     137     encoding_duration = datetime.datetime.now() - start
#
# File ~\anaconda3\lib\site-packages\pymongo\message.py:1131, in _raise_document_too_large(operation, doc_size, max_size)
#    1129 """Internal helper for raising DocumentTooLarge."""
#    1130 if operation == "insert":
# -> 1131     raise DocumentTooLarge("BSON document too large (%d bytes)"
#    1132                            " - the connected server supports"
#    1133                            " BSON document sizes up to %d"
#    1134                            " bytes." % (doc_size, max_size))
#    1135 else:
#    1136     # There's nothing intelligent we can say
#    1137     # about size for update and delete
#    1138     raise DocumentTooLarge("%r command document too large" % (operation,))
#
# DocumentTooLarge: BSON document too large (266663953 bytes) - the connected server supports BSON document sizes up to 16793598 bytes.
