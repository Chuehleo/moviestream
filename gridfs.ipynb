# %%
from pymongo import MongoClient
from gridfs import GridFS

# %%
client = MongoClient()
movie_database = client.movie_database

# %%
fs = GridFS(movie_database)

# open the video file in binary mode and write it to GridFS
with open('public/videos/tabletennis.mp4', 'rb') as f:
    video_id = fs.put(f, filename='tabletennis.mp4')
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\gridfs\__init__.py:132, in GridFS.put(self, data, **kwargs)
#     131 try:
# --> 132     grid_file.write(data)
#     133 finally:
#
# File ~\anaconda3\lib\site-packages\gridfs\grid_file.py:397, in GridIn.write(self, data)
#     396 while to_write and len(to_write) == self.chunk_size:
# --> 397     self.__flush_data(to_write)
#     398     to_write = read(self.chunk_size)
#
# File ~\anaconda3\lib\site-packages\gridfs\grid_file.py:276, in GridIn.__flush_data(self, data)
#     274 """Flush `data` to a chunk.
#     275 """
# --> 276 self.__ensure_indexes()
#     277 if 'md5' in self._file:
#
# File ~\anaconda3\lib\site-packages\gridfs\grid_file.py:219, in GridIn.__ensure_indexes(self)
#     218 _disallow_transactions(self._session)
# --> 219 self.__create_index(self._coll.files, _F_INDEX, False)
# ...
